# %% [markdown]
# # Imports

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import convertapi
from pprint import pprint
import translators as ts
# Out:
# Using Canada server backend.

# %% [markdown]
# # Functions

# %%
def get_source(url):
    try:
        session = requests.Session()
        response = session.get(url)
        return response.content
    except requests.exceptions.RequestException as e:
        print("Error ->", e)
        return None
    except:
        print("Other Error")
        return None


def get_local_sources(html_filenames):
    local_sources = []
    for html_filename in html_filenames:
        with open(html_filename) as html_file:
            local_source = html_file.read()
            local_sources.append(local_source)
    return local_sources


def download_and_get_doc_filenames(urls):
    filenames = []
    filename_suffix = 1
    for url in urls:
        filename = f"word_doc{filename_suffix:03d}.doc"
        data = requests.get(url)
        with open(filename, 'wb')as file:
            file.write(data.content)
        filenames.append(filename)
        filename_suffix = filename_suffix + 1
    return filenames
    
        
def get_urls(soup):
    doc_links = soup.find_all('a', {'class':'link_info'})
    urls = [doc_links[i]['href'] for i in range(len(doc_links))]
    return urls


def convert_and_get_html_filenames(doc_filenames):
    convertapi.api_secret = CONVERT_API_KEY
    html_filenames = []
    for doc_filename in doc_filenames:
        html_filename = f'{doc_filename[0:-4]}.html'
        convertapi.convert('html', {
            'File': doc_filename
        }, from_format = 'doc').save_files(html_filename)
        html_filenames.append(html_filename)
    return html_filenames

def get_local_soups(local_sources):
    return [BeautifulSoup(local_source, 'html.parser') for local_source in local_sources]


def get_first_table(table):
    cells = table.find_all('td')
    left = cells[0]
    left_text = left.get_text()
    left_text = left_text.replace('\n', '')
    right = cells[1]
    right_text = right.get_text()
    right_text = right_text.replace('\n', '')
    left_text = ts.google(left_text)
    right_text = ts.google(right_text)
    return left_text, right_text

def get_table_df(table):
    return pd.read_html(str(table), header=0)[0]

def google_translate(thing):
    try:
        return ts.google(thing)
    except:
        return thing
    
    
def get_table_dfs_en(table_dfs):
    table_dfs_en = []
    for table_df in table_dfs:
        table_df_en = table_df.applymap(google_translate, 'ignore')
        table_df_en.set_axis(list(map(ts.google, list(table_df_en.columns))), axis=1, inplace=True)
        table_dfs_en.append(table_df_en)
    return table_dfs_en

def get_person_name(soup):
    try:
        name = soup.find_all('p', {'style':'text-align:center'})[3].get_text()
        return ts.google(name)
    except:
        return ''

# %% [markdown]
# # Global Variables
# - `URL`: The URL of the page whose word documents we will be scraping
# - `CONVERT_API_KEY`: The script converts word (`.doc`) into `.html` files for easy scraping. This service is provided by `convertapi.com`. The free tier is currently used. The paid tier should be considered if limit is reached or requests are throttled.
# - `START`, `STOP`: Provides the start and stop index of the `.doc` files to be captured (inclusive `START` to exlusive `STOP`, 0 is first index). For example, `START = 0; STOP = 1` captures only the first doc file, `START = 0; STOP = 3` captures the first three, `START = 3; STOP = 5` captures the forth and fifth. The max value for `STOP` is `368`

# %%
URL = 'http://www.council.gov.ru/structure/machinery/vacancies/property/'
CONVERT_API_KEY = 'Ez96VL6BxeWjmniA'
START = 1
STOP = 2  # 368 is max

# %% [markdown]
# # Script

# %% [markdown]
# ## Download `.doc` Files and convert to `.html`

# %%
# source = get_source(URL)
soup = BeautifulSoup(source, 'html.parser')
urls = get_urls(soup)

urls = urls[START:STOP]
# doc_filenames = download_and_get_doc_filenames(urls)
# html_filenames = convert_and_get_html_filenames(doc_filenames)
# Out:
# <!DOCTYPE html>
#
# <html class="no-js fonts-loaded" itemscope="itemscope" itemtype="http://schema.org/WebPage" lang="ru" prefix="og: http://ogp.me/ns#" xmlns="http://www.w3.org/1999/xhtml">
# <head><meta content="csrftoken" name="csrf-token-name"/>
# <meta content="1714d571379d0c78b2acf27acbd5e5930275d06dec8b77410d3ecfe2da76ad52e8ba9eae30ccd1c1" name="csrf-token-value"/>
# <meta content="Ajax-Token" name="hmac-token-name"/>
# <title>
#                 Сведения о доходах, расходах, об имуществе и обязательствах имущественного характера |
#
#             Совет Федерации Федерального Собрания Российской Федерации
#         </title>
# <meta charset="utf-8"/>
# <meta content="Официальный сайт Совета Федерации — верхней палаты российского парламента. Последние новости, фото и видео-материалы, пресс-конференции. Информация о деятельности сенаторов и Председателя СФ Валентины Матвиенко. Работа членов Совета Федерации в регионах" name="description"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width,initial-scale=1,minimum-scale=1" name="viewport"/>
# <meta content="" name="keywords"/>
# <meta content="ru" itemprop="inLanguage"/>
# <meta content="index, follow" name="robots"/>
# <meta content="noyaca" name="robots">
# <link href="/static/img/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/static/img/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/static/img/favicons/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="/static/img/apple-icons/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/static/img/apple-icons/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="/static/img/apple-icons/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/static/img/apple-icons/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/static/img/apple-icons/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/static/img/apple-icons/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/static/img/apple-icons/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="/static/img/apple-icons/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="/static/img/apple-icons/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <meta content="Совет Федерации Федерального Собрания Российской Федерации" property="og:site_name"/>
# <meta content="336065043203397" property="fb:pages"/>
# <meta content="0646acf6c516da58" name="yandex-verification"/><link href="/static/css/app.css?75278630b1" media="all" rel="stylesheet" type="text/css"/>
# <link href="/static/css/print.css" media="print" rel="stylesheet">
# <!--[if IE ]><link rel="stylesheet" type="text/css" href="/static/css/ie.css?bbebc3c33c" media="all"><[endif]-->
# </link></meta></head>
# <body><noscript><img alt="" height="0" src="/f3035634c7c088d65605216b8687fc3c.gif" width="0"/></noscript>
# <div class="main_layout">
# <div class="header">
# <header role="banner">
# <div class="header__overlay"></div>
# <div class="header__caption_grey"></div>
# <div class="content__in">
# <a aria-controls="main-nav" class="header__toggle_menu" href="#footer" role="button">
# <span class="header__toggle_wrapper_elements">
# <span class="header__toggle_element_first"></span>
# <span class="header__toggle_element_second"></span>
# <span class="header__toggle_element_third"></span>
# </span>
# <span class="header__caption_small header__caption_menu">Меню</span>
# <span class="header__caption_small header__menu_close">Закрыть</span>
# </a>
# <ul class="header_titles filters_center">
# <li class="header_titles_item last">
# <a class="header__title" href="/" title="Совет Федерации Федерального собрания Российской Федерации">
# <span class="header__title_main">Совет Федерации</span>
# <span class="header__title_caption">Федерального собрания Российской Федерации</span>
# <i class="header_title_logo"></i>
# </a>
# </li>
# </ul>
# <a aria-label="Поиск по сайту" class="search" href="/services/search/" role="button">
# <div aria-hidden="true" class="search__icon">
# <span class="circle"></span>
# <span class="handle"></span>
# </div>
# <span aria-hidden="true" class="header__caption_small header__menu_close">
#                             Закрыть</span>
# </a>
# <a class="header__auth" href="/users/login/">
# <i></i>
# <span class="header__caption_small">Вход</span>
# </a>
# </div>
# <div class="header__channel media__video media__video_small" style="background-image: url('/static/img/bg/player_header.jpg?009a5a19fa')">
# <a href="/events/streams/tv/">
# <span class="grayscale_filter"></span>
# <span class="header__channel_player">
# <i></i>
# <span class="header__channel_caption">
#                     Эфир
#                 </span>
# </span>
# </a>
# </div>
# </header>
# </div>
# <aside aria-hidden="true" class="search__form_wrapper modal__wrapper" role="search">
# <div class="content__in">
# <form action="/services/search/" class="search__form" id="topform" method="get">
# <fieldset>
# <div><input name="query" placeholder="Поиск по сайту" title="Поиск по сайту" type="text"/>
# </div>
# <button class="search__form_button" type="submit">
# <span>Найти</span>
# </button>
# </fieldset>
# </form>
# </div>
# </aside>
# <div class="main-menu modal__wrapper" id="main-nav">
# <nav aria-hidden="true" aria-label="Основное меню" id="main-menu" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement" role="navigation">
# <div class="main-menu__in content__in">
# <div aria-label="Карта портала" class="cols">
# <div class="main-menu__col col col_4">
# <h2 class="main-menu__title main-menu__title_group"><span>Сервисы</span></h2>
# <ul class="main-menu__list">
# <li class="main-menu__item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/services/contacts/" itemprop="url">Контакты</a>
# </li>
# <li class="main-menu__item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/services/messages/" itemprop="url">Обращения граждан</a>
# </li>
# <li class="main-menu__item main-menu__item_hidden" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/services/search/" itemprop="url">Поиск</a>
# </li>
# <li class="main-menu__item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/services/discussions/" itemprop="url">Обсуждения</a>
# </li>
# <li class="main-menu__item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/services/subscribe/" itemprop="url">Подписка</a>
# </li>
# <li class="main-menu__item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/services/reference/" itemprop="url">Справочник</a>
# </li>
# <li class="main-menu__item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/services/sitemap/" itemprop="url">Карта сайта</a>
# </li>
# <li class="main-menu__item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/services/excursions/" itemprop="url">Экскурсии</a>
# </li>
# <li class="main-menu__item main-menu__item_special" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="http://special.council.gov.ru/" itemprop="url"><i></i>
# <span itemprop="name">Версия для людей с ограниченными возможностями</span></a>
# </li>
# <li class="main-menu__item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/en/" itemprop="url" rel="external">English</a>
# </li>
# </ul>
# </div>
# <div class="main-menu__col col col_4">
# <h2 class="main-menu__title main-menu__title_group"><span>Структура</span></h2>
# <ul class="main-menu__list">
# <li class="main-menu__item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/structure/council/" itemprop="url">Совет Федерации</a>
# </li>
# <li class="main-menu__item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/structure/administration/" itemprop="url">Руководство</a>
# </li>
# <li class="main-menu__item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/structure/chamber/" itemprop="url">Совет Палаты</a>
# </li>
# <li class="main-menu__item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/structure/members/" itemprop="url">Сенаторы</a>
# </li>
# <li class="main-menu__item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/structure/committees/" itemprop="url">Комитеты СФ</a>
# </li>
# <li class="main-menu__item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/structure/commissions/" itemprop="url">Комиссии</a>
# </li>
# <li class="main-menu__item main-menu__item_active" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/structure/machinery/" itemprop="url">Аппарат СФ</a>
# </li>
# <li class="main-menu__item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/structure/chairman_authority/" itemprop="url">Органы при Председателе</a>
# </li>
# <li class="main-menu__item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/structure/sf_authority/" itemprop="url">Органы при Совете Федерации</a>
# </li>
# <li class="main-menu__item main-menu__item_external" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="http://szrf.km.duma.gov.ru/" itemprop="url" target="_blank"><i></i>Совет законодателей при Федеральном Собрании</a>
# </li>
# </ul>
# </div>
# <div class="main-menu__col col col_4">
# <h2 class="main-menu__title main-menu__title_group"><span>Деятельность</span></h2>
# <ul class="main-menu__list">
# <li class="main-menu__item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/activity/meetings/" itemprop="url">Заседания СФ</a>
# </li>
# <li class="main-menu__item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/activity/legislation/" itemprop="url">Законодательная деятельность</a>
# </li>
# <li class="main-menu__item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/activity/documents/" itemprop="url">Документы</a>
# </li>
# <li class="main-menu__item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/activity/crosswork/" itemprop="url">Межпарламентская деятельность</a>
# </li>
# <li class="main-menu__item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/activity/regions/" itemprop="url">Взаимодействие с регионами</a>
# </li>
# <li class="main-menu__item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/activity/activities/" itemprop="url">Мероприятия</a>
# </li>
# <li class="main-menu__item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/activity/anticorruption/" itemprop="url">Противодействие коррупции</a>
# </li>
# <li class="main-menu__item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/activity/reports/" itemprop="url">Ежегодные отчеты сенаторов</a>
# </li>
# <li class="main-menu__item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/activity/analytics/" itemprop="url">Издания и аналитические материалы</a>
# </li>
# </ul>
# </div>
# <div class="main-menu__col col col_4">
# <h2 class="main-menu__title main-menu__title_group"><span>События</span></h2>
# <ul class="main-menu__list">
# <li class="main-menu__item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/events/main_themes/" itemprop="url">Главные темы</a>
# </li>
# <li class="main-menu__item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/events/news/" itemprop="url">Все новости</a>
# </li>
# <li class="main-menu__item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/events/chairman/" itemprop="url">Председатель</a>
# </li>
# <li class="main-menu__item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/events/committees/" itemprop="url">Комитеты</a>
# </li>
# <li class="main-menu__item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/events/senators/" itemprop="url">Сенаторы в регионах</a>
# </li>
# <li class="main-menu__item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/events/conference/" itemprop="url">Пресс-конференции</a>
# </li>
# <li class="main-menu__item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/events/blogs/" itemprop="url">Блоги сенаторов</a>
# </li>
# <li class="main-menu__item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/events/multimedia/" itemprop="url">Мультимедиа</a>
# </li>
# <li class="main-menu__item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/events/streams/" itemprop="url">Телеканал и прямые трансляции</a>
# </li>
# <li class="main-menu__item main-menu__item_smi" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/events/smi/" itemprop="url"><i></i>Для СМИ</a>
# </li>
# </ul>
# </div>
# <div class="main-menu__col main-menu__col-hidden main-menu__item">
# <h2 class="main-menu__title"><a href="/services/search/">Поиск</a></h2>
# </div>
# </div>
# <div class="main-menu__info">
# <div class="main-menu_social main-menu__col">
# <ul class="social__list">
# <li class="social__item">
# <a class="social__link main-menu_social_icon main-menu_vk" href="https://vk.com/sovfedinfo" target="_blank"><i></i>vk</a>
# </li>
# <li class="social__item">
# <a class="social__link main-menu_social_icon main-menu_youtube" href="http://www.youtube.com/user/sovfedinfo" target="_blank"><i></i>Youtube</a>
# </li>
# <li class="social__item social__item_lj">
# <a class="social__link main-menu_social_icon main-menu_livej" href="https://ok.ru/sovfedinfo" target="_blank"><i></i>Одноклассники</a>
# </li>
# <li class="social__item">
# <a class="social__link main-menu_social_icon main-menu_telegram" href="https://t.me/sovfedofficial " target="_blank"><i></i>Телеграм</a>
# </li>
# <li class="social__item">
# <a class="social__link main-menu_social_icon main-menu_rutube" href="https://rutube.ru/channel/23489764/" target="_blank"><i></i>Rutube</a>
# </li>
# <li class="social__item">
# <a class="social__link main-menu_social_icon main-menu_flickr" href="https://www.flickr.com/photos/sf_press/albums" target="_blank"><i></i>Flickr</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </nav>
# </div>
# <div class="wrapper">
# <div class="main__content_wrapper">
# <main role="main">
# <p class="title_small page_section"><a href="/structure/machinery/" title="Кадровое обеспечение">Кадровое обеспечение</a></p>
# <div class="content__in">
# <h1 class="title_page title_large title_large_dark">Сведения о доходах, расходах, об имуществе и обязательствах имущественного характера</h1>
# </div>
# <div class="content__in">
# <ul class="filters filters_small filters_center filters_tabs">
# <li class="filters__item">
# <a class="filters__link is-active" href="#sf">Сенаторы РФ</a></li>
# <li class="filters__item">
# <a class="filters__link" href="#mach">Сотрудники аппарата</a></li>
# </ul>
# </div>
# <div class="content__in content__in_bottom">
# <div class="is-hidden-block" id="mach">
# <div class="attach__item attach__item_file attach__item_wide">
# <a class="u-url attach__link" download="2021.doc" href="http://council.gov.ru/media/income/2qK0UUgp5oxsq2del75guGd7pbONygNo.doc" title="2021">
# <i class="attach__icon"></i>
# <span class="attach__title attach__title_wide">2021</span>
# <span class="lead attach__lead">
#                                 Сведения о доходах, расходах, об имуществе и обязательствах
#                                 имущественного характера федеральных государственных гражданских служащих
#                                 аппарата Совета Федерации
#                             </span>
# </a>
# </div>
# <div class="attach__item attach__item_file attach__item_wide">
# <a class="u-url attach__link" download="2020.doc" href="http://council.gov.ru/media/income/QIqCANdP2qZYaJ00rAe7rkwSFPt5FysA.doc" title="2020">
# <i class="attach__icon"></i>
# <span class="attach__title attach__title_wide">2020</span>
# <span class="lead attach__lead">
#                                 Сведения о доходах, расходах, об имуществе и обязательствах
#                                 имущественного характера федеральных государственных гражданских служащих
#                                 аппарата Совета Федерации
#                             </span>
# </a>
# </div>
# <div class="attach__item attach__item_file attach__item_wide">
# <a class="u-url attach__link" download="2019.doc" href="http://council.gov.ru/media/income/ZANzMP3fpWgtz38PmDf8ZB2y51eBQAaZ.doc" title="2019">
# <i class="attach__icon"></i>
# <span class="attach__title attach__title_wide">2019</span>
# <span class="lead attach__lead">
#                                 Сведения о доходах, расходах, об имуществе и обязательствах
#                                 имущественного характера федеральных государственных гражданских служащих
#                                 аппарата Совета Федерации
#                             </span>
# </a>
# </div>
# <div class="attach__item attach__item_file attach__item_wide">
# <a class="u-url attach__link" download="2018.doc" href="http://council.gov.ru/media/income/SKLvZqwyzpmp5W2r8RybmEnr4tLQujsc.doc" title="2018">
# <i class="attach__icon"></i>
# <span class="attach__title attach__title_wide">2018</span>
# <span class="lead attach__lead">
#                                 Сведения о доходах, расходах, об имуществе и обязательствах
#                                 имущественного характера федеральных государственных гражданских служащих
#                                 аппарата Совета Федерации
#                             </span>
# </a>
# </div>
# <div class="attach__item attach__item_file attach__item_wide">
# <a class="u-url attach__link" download="2017.doc" href="http://council.gov.ru/media/income/Zv1gZs87JrhgWpeD3DIAfHes2xUWBoUq.doc" title="2017">
# <i class="attach__icon"></i>
# <span class="attach__title attach__title_wide">2017</span>
# <span class="lead attach__lead">
#                                 Сведения о доходах, расходах, об имуществе и обязательствах
#                                 имущественного характера федеральных государственных гражданских служащих
#                                 аппарата Совета Федерации
#                             </span>
# </a>
# </div>
# <div class="attach__item attach__item_file attach__item_wide">
# <a class="u-url attach__link" download="2016.docx" href="http://council.gov.ru/media/income/V0CSEehADdtMMpjyOorC0nvDSRsKAT1C.docx" title="2016">
# <i class="attach__icon"></i>
# <span class="attach__title attach__title_wide">2016</span>
# <span class="lead attach__lead">
#                                 Сведения о доходах, расходах, об имуществе и обязательствах
#                                 имущественного характера федеральных государственных гражданских служащих
#                                 аппарата Совета Федерации
#                             </span>
# </a>
# </div>
# <div class="attach__item attach__item_file attach__item_wide">
# <a class="u-url attach__link" download="2015.doc" href="http://council.gov.ru/media/income/wpJAX98jstelipNoF3Wa6XWZ8JqvISjE.doc" title="2015">
# <i class="attach__icon"></i>
# <span class="attach__title attach__title_wide">2015</span>
# <span class="lead attach__lead">
#                                 Сведения о доходах, расходах, об имуществе и обязательствах
#                                 имущественного характера федеральных государственных гражданских служащих
#                                 аппарата Совета Федерации
#                             </span>
# </a>
# </div>
# <div class="attach__item attach__item_file attach__item_wide">
# <a class="u-url attach__link" download="2014.doc" href="http://council.gov.ru/media/income/41d557cbc58476860ed3.doc" title="2014">
# <i class="attach__icon"></i>
# <span class="attach__title attach__title_wide">2014</span>
# <span class="lead attach__lead">
#                                 Сведения о доходах, расходах, об имуществе и обязательствах
#                                 имущественного характера федеральных государственных гражданских служащих
#                                 аппарата Совета Федерации
#                             </span>
# </a>
# </div>
# <div class="attach__item attach__item_file attach__item_wide attach__item_wide_special">
# <a class="u-url attach__link" download="2013.doc" href="http://council.gov.ru/media/income/41d562508f023b92f4a0.doc" title="2013">
# <i class="attach__icon"></i>
# <span class="attach__title attach__title_wide">2013</span>
# <span class="lead attach__lead">
#                                 Сведения о доходах, расходах, об имуществе и обязательствах
#                                 имущественного характера федеральных государственных гражданских служащих
#                                 аппарата Совета Федерации
#                             </span>
# </a>
# </div>
# <hr class="sep sep_machinery"/>
# <p class="text">Сведения о доходах, расходах, об имуществе и обязательствах
#                 имущественного характера федеральных государственных гражданских
#                 служащих аппарата Совета Федерации за 2012 год представлены в
#                 списке ниже в алфавитном порядке:</p>
# <div class="letters_wrapper">
# <div class="letters_container">
# <div class="content__in">
# <div class="block__letters">
# <a class="nav_letter" href="#mach-letter-А">А</a>
# <a class="nav_letter" href="#mach-letter-Б">Б</a>
# <a class="nav_letter" href="#mach-letter-В">В</a>
# <a class="nav_letter" href="#mach-letter-Г">Г</a>
# <a class="nav_letter" href="#mach-letter-Д">Д</a>
# <a class="nav_letter" href="#mach-letter-Е">Е</a>
# <a class="nav_letter" href="#mach-letter-Ж">Ж</a>
# <a class="nav_letter" href="#mach-letter-З">З</a>
# <a class="nav_letter" href="#mach-letter-И">И</a>
# <a class="nav_letter" href="#mach-letter-К">К</a>
# <a class="nav_letter" href="#mach-letter-Л">Л</a>
# <a class="nav_letter" href="#mach-letter-М">М</a>
# <a class="nav_letter" href="#mach-letter-Н">Н</a>
# <a class="nav_letter" href="#mach-letter-О">О</a>
# <a class="nav_letter" href="#mach-letter-П">П</a>
# <a class="nav_letter" href="#mach-letter-Р">Р</a>
# <a class="nav_letter" href="#mach-letter-С">С</a>
# <a class="nav_letter" href="#mach-letter-Т">Т</a>
# <a class="nav_letter" href="#mach-letter-У">У</a>
# <a class="nav_letter" href="#mach-letter-Ф">Ф</a>
# <a class="nav_letter" href="#mach-letter-Х">Х</a>
# <a class="nav_letter" href="#mach-letter-Ц">Ц</a>
# <a class="nav_letter" href="#mach-letter-Ч">Ч</a>
# <a class="nav_letter" href="#mach-letter-Ш">Ш</a>
# <a class="nav_letter is-disabled" href="#mach-letter-Щ">Щ</a>
# <a class="nav_letter is-disabled" href="#mach-letter-Э">Э</a>
# <a class="nav_letter is-disabled" href="#mach-letter-Ю">Ю</a>
# <a class="nav_letter" href="#mach-letter-Я">Я</a>
# </div>
# </div>
# </div>
# </div>
# <div class="group-by-letter is-first">
# <h3 class="title_main title_red filter_letter" id="mach-letter-А">А</h3>
# <div class="by_letter">
# <div class="council_block">
# <h3 class="council_title" data-title="Абрамов Михаил Борисович">Абрамов Михаил Борисович</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1ab752dace.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Агальцов Валерий Станиславович">Агальцов Валерий Станиславович</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1aba73a115.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Азаров Виталий Михайлович">Азаров Виталий Михайлович</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1abd66ebb0.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Акжигитова Алла Николаевна">Акжигитова Алла Николаевна</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1ac0591cf7.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Алешин Владимир Васильевич">Алешин Владимир Васильевич</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1ac36556ad.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Алешкин Алексей Алексеевич">Алешкин Алексей Алексеевич</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1ac67a5412.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Алиева Ирина Вячеславовна">Алиева Ирина Вячеславовна</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1ac979026d.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Аникеева Ольга Борисовна">Аникеева Ольга Борисовна</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1acc6c9620.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Анисимов Виктор Анатольевич">Анисимов Виктор Анатольевич</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1acf64a852.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Анисимов Николай Анисимович">Анисимов Николай Анисимович</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1ad274207b.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Афонина Лидия Яковлевна">Афонина Лидия Яковлевна</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1ad57300a4.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Ахметов Вячеслав Александрович">Ахметов Вячеслав Александрович</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1ad86b3e50.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# </div>
# </div>
# <div class="group-by-letter">
# <h3 class="title_main title_red filter_letter" id="mach-letter-Б">Б</h3>
# <div class="by_letter">
# <div class="council_block">
# <h3 class="council_title" data-title="Багмет Лилия Андреевна">Багмет Лилия Андреевна</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1adb62ac71.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Байдина Ольга Валерьевна">Байдина Ольга Валерьевна</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1ade590d39.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Бакланов Павел Анатольевич">Бакланов Павел Анатольевич</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1ae1503354.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Банхаева Фатима Хаджибикаровна">Банхаева Фатима Хаджибикаровна</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1ae45cd99e.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Барбашин Игорь Викторович">Барбашин Игорь Викторович</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1ae760d01f.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Бардина Елена Степановна">Бардина Елена Степановна</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1aea577a07.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Баркаган Александр Валерьевич">Баркаган Александр Валерьевич</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1aed4eaa83.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Барсамов Владимир Александрович">Барсамов Владимир Александрович</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1af045acbb.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Болдырева Раиса Степановна">Болдырева Раиса Степановна</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1af35e2602.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Брюхнова Екатерина Алековна">Брюхнова Екатерина Алековна</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1af65edc12.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Бубличенко Наталия Валентиновна">Бубличенко Наталия Валентиновна</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1af972e2f3.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Бурнаков Александр Сергеевич">Бурнаков Александр Сергеевич</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1afc6e6e79.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Буслаева Людмила Александровна">Буслаева Людмила Александровна</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1aff653d8e.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Бусоргин Глеб Павлович">Бусоргин Глеб Павлович</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1b02606636.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# </div>
# </div>
# <div class="group-by-letter">
# <h3 class="title_main title_red filter_letter" id="mach-letter-В">В</h3>
# <div class="by_letter">
# <div class="council_block">
# <h3 class="council_title" data-title="Ващенко Николай Филиппович">Ващенко Николай Филиппович</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1b05816829.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Векшина Елена Владимировна">Векшина Елена Владимировна</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1b088140bd.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Вершинская Светлана Владимировна">Вершинская Светлана Владимировна</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1b0b742dc0.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Веселов Владимир Игнатьевич">Веселов Владимир Игнатьевич</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1b0e6b38c9.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Ветров Александр Григорьевич">Ветров Александр Григорьевич</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1b1166f8b6.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Викторов Валерьян Николаевич">Викторов Валерьян Николаевич</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1b148c5882.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Владимиров Дмитрий Георгиевич">Владимиров Дмитрий Георгиевич</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1b178f382b.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Власова Людмила Михайловна">Власова Людмила Михайловна</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1b1a8bc195.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Вознесенский Станислав Феликсович">Вознесенский Станислав Феликсович</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1b1d867e35.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Волкова Елена Васильевна">Волкова Елена Васильевна</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1b20865018.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Волкова Ольга Витальевна">Волкова Ольга Витальевна</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1b238525c3.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Воронина Светлана Владимировна">Воронина Светлана Владимировна</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1b26a26766.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Воропаев Василий Александрович">Воропаев Василий Александрович</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1b29a6ad4e.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# </div>
# </div>
# <div class="group-by-letter">
# <h3 class="title_main title_red filter_letter" id="mach-letter-Г">Г</h3>
# <div class="by_letter">
# <div class="council_block">
# <h3 class="council_title" data-title="Гаврилов Валерий Васильевич">Гаврилов Валерий Васильевич</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1b2c9db541.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Гаврилюк Александр Евсеевич">Гаврилюк Александр Евсеевич</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1b2f94273c.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Гавришин Михаил Петрович">Гавришин Михаил Петрович</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1b32942936.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Глигич-Золотарева Милена Валериевна">Глигич-Золотарева Милена Валериевна</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1b35add2dc.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Говердовский Евгений Евгеньевич">Говердовский Евгений Евгеньевич</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1b38c191e5.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Голубев Сергей Андреевич">Голубев Сергей Андреевич</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1b3bc19a98.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Громова Татьяна Федоровна">Громова Татьяна Федоровна</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1b3eb8bf1d.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Гыскэ Анатолий Викторович">Гыскэ Анатолий Викторович</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1b41b78bd8.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# </div>
# </div>
# <div class="group-by-letter">
# <h3 class="title_main title_red filter_letter" id="mach-letter-Д">Д</h3>
# <div class="by_letter">
# <div class="council_block">
# <h3 class="council_title" data-title="Давиденко Сергей Николаевич">Давиденко Сергей Николаевич</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1b44c8c8c1.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Данилова Вера Евгеньевна">Данилова Вера Евгеньевна</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1b47d04250.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Доронина Ирина Эдуардовна">Доронина Ирина Эдуардовна</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1b4ad32c65.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# </div>
# </div>
# <div class="group-by-letter">
# <h3 class="title_main title_red filter_letter" id="mach-letter-Е">Е</h3>
# <div class="by_letter">
# <div class="council_block">
# <h3 class="council_title" data-title="Евсеева Ирина Михайловна">Евсеева Ирина Михайловна</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1b4dd75532.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Евтеева Марина Константиновна">Евтеева Марина Константиновна</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1b50e31d99.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Ермакова Ирина Анатольевна">Ермакова Ирина Анатольевна</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1b53f88c9c.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# </div>
# </div>
# <div class="group-by-letter">
# <h3 class="title_main title_red filter_letter" id="mach-letter-Ж">Ж</h3>
# <div class="by_letter">
# <div class="council_block">
# <h3 class="council_title" data-title="Желнов Василий Степанович">Желнов Василий Степанович</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1b5726a73a.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Жилич Юлия Васильевна">Жилич Юлия Васильевна</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1b5a21b59f.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# </div>
# </div>
# <div class="group-by-letter">
# <h3 class="title_main title_red filter_letter" id="mach-letter-З">З</h3>
# <div class="by_letter">
# <div class="council_block">
# <h3 class="council_title" data-title="Замай Вера Васильевна">Замай Вера Васильевна</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1b601829bc.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Золин Владимир Александрович">Золин Владимир Александрович</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1b631b996f.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Зубков Юрий Викторович">Зубков Юрий Викторович</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1b66309cf4.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# </div>
# </div>
# <div class="group-by-letter">
# <h3 class="title_main title_red filter_letter" id="mach-letter-И">И</h3>
# <div class="by_letter">
# <div class="council_block">
# <h3 class="council_title" data-title="Иваненко Сергей Игоревич">Иваненко Сергей Игоревич</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1b6938cb24.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Иванов Алексей Геннадьевич">Иванов Алексей Геннадьевич</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1b6c379675.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Иванов Николай Иванович">Иванов Николай Иванович</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/41d4642a7a1b6fe74add.doc">Сведения о
#                                         доходах за 2012 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# ...
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Хохлова Ольга Николаевна">Хохлова Ольга Николаевна</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/4dmbDAs1tgPD2dccRazEeyHALMqASAHt.doc">Сведения о
#                                         доходах за 2021 год</a>
# </p>
# </div>
# </div>
# </div>
# </div>
# <div class="group-by-letter">
# <h3 class="title_main title_red filter_letter" id="sf-letter-Ц">Ц</h3>
# <div class="by_letter">
# <div class="council_block">
# <h3 class="council_title" data-title="Цеков Сергей Павлович">Цеков Сергей Павлович</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/AeTIRaGZbgY00TtjLO7mQwUGQlXagjuu.doc">Сведения о
#                                         доходах за 2021 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Цепкин Олег Владимирович">Цепкин Олег Владимирович</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/n0g0U7d8GLwAMx0uXcXtoymRxrFUmSkd.doc">Сведения о
#                                         доходах за 2021 год</a>
# </p>
# </div>
# </div>
# </div>
# </div>
# <div class="group-by-letter">
# <h3 class="title_main title_red filter_letter" id="sf-letter-Ч">Ч</h3>
# <div class="by_letter">
# <div class="council_block">
# <h3 class="council_title" data-title="Чернышев Андрей Владимирович">Чернышев Андрей Владимирович</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/d9N7YP0IMup0FNn8MCDedUymtFP9dbAr.doc">Сведения о
#                                         доходах за 2021 год</a>
# </p>
# </div>
# </div>
# </div>
# </div>
# <div class="group-by-letter">
# <h3 class="title_main title_red filter_letter" id="sf-letter-Ш">Ш</h3>
# <div class="by_letter">
# <div class="council_block">
# <h3 class="council_title" data-title="Шевченко Андрей Анатольевич">Шевченко Андрей Анатольевич</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/A7k84ADEqkzl5ANaOcPdVAic8ZCniX3E.doc">Сведения о
#                                         доходах за 2021 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Шейкин Артем Геннадьевич">Шейкин Артем Геннадьевич</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/g20hDJPFow29xTYJJQ51rbCdAA7qzMVt.doc">Сведения о
#                                         доходах за 2021 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Широков Анатолий Иванович">Широков Анатолий Иванович</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/PLXH18g71c57mKFJOkY07Fm3rFtAMEWa.doc">Сведения о
#                                         доходах за 2021 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Шумилова Елена Борисовна">Шумилова Елена Борисовна</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/AGjHMAsinyGoEB0jcVnRoIaicE5mAnxZ.doc">Сведения о
#                                         доходах за 2021 год</a>
# </p>
# </div>
# </div>
# </div>
# </div>
# <div class="group-by-letter">
# <h3 class="title_main title_red filter_letter" id="sf-letter-Я">Я</h3>
# <div class="by_letter">
# <div class="council_block">
# <h3 class="council_title" data-title="Ягубов Геннадий Владимирович">Ягубов Геннадий Владимирович</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/ADHILTiF1360OA3wT4FuRlAlSEIAbY2D.doc">Сведения о
#                                         доходах за 2021 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Ялалов Ирек Ишмухаметович">Ялалов Ирек Ишмухаметович</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/BDyVXBw1E7CjMeaXpKAFBM6Eyoe8e4Gb.doc">Сведения о
#                                         доходах за 2021 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Ярошук Александр Георгиевич">Ярошук Александр Георгиевич</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/pT4NFOmBU8TCTQAkpuUEfdnVjYhcgkfP.doc">Сведения о
#                                         доходах за 2021 год</a>
# </p>
# </div>
# </div>
# <div class="council_block">
# <h3 class="council_title" data-title="Яцкин Андрей Владимирович">Яцкин Андрей Владимирович</h3>
# <div class="links__wrapper is-visible-block">
# <p class="links_container">
# <a class="link_info" href="http://council.gov.ru/media/property/doc/dYRFD3AQ0RcUCeVklsHds7bVlQIGb8w6.doc">Сведения о
#                                         доходах за 2021 год</a>
# </p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </main>
# </div>
# <footer id="footer" itemscope="itemscope" itemtype="http://schema.org/WPFooter" role="contentinfo">
# <div class="footer">
# <div class="footer__in content__in">
# <div class="for_mobile footer__top_mobile" hidden="hidden">
# <div class="footer__top_logo"></div>
# <h3 class="footer__top_title">Совет Федерации</h3>
# <p class="footer__top_info">Федерального собрания Российской федерации</p>
# </div>
# <div aria-label="Карта портала" class="cols footer_menu_wrapper">
# <div class="footer__col col col_4">
# <h2 class="footer_title"><span class="footer_title_link">Сервисы</span></h2>
# <ul class="footer_list">
# <li class="footer_list_item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/services/contacts/" itemprop="url">Контакты</a>
# </li>
# <li class="footer_list_item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/services/messages/" itemprop="url">Обращения граждан</a>
# </li>
# <li class="footer_list_item footer_list_item_search" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/services/search/" itemprop="url"><i></i>Поиск</a>
# </li>
# <li class="footer_list_item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/services/discussions/" itemprop="url">Обсуждения</a>
# </li>
# <li class="footer_list_item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/services/subscribe/" itemprop="url">Подписка</a>
# </li>
# <li class="footer_list_item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/services/reference/" itemprop="url">Справочник</a>
# </li>
# <li class="footer_list_item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/services/sitemap/" itemprop="url">Карта сайта</a>
# </li>
# <li class="footer_list_item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/services/excursions/" itemprop="url">Экскурсии</a>
# </li>
# <li class="footer_list_item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/en/" itemprop="url" rel="external">English</a>
# </li>
# </ul>
# </div>
# <div class="footer__col col col_4">
# <h2 class="footer_title"><span class="footer_title_link">Структура</span></h2>
# <ul class="footer_list">
# <li class="footer_list_item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/structure/council/" itemprop="url">Совет Федерации</a>
# </li>
# <li class="footer_list_item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/structure/administration/" itemprop="url">Руководство</a>
# </li>
# <li class="footer_list_item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/structure/chamber/" itemprop="url">Совет Палаты</a>
# </li>
# <li class="footer_list_item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/structure/members/" itemprop="url">Сенаторы</a>
# </li>
# <li class="footer_list_item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/structure/committees/" itemprop="url">Комитеты СФ</a>
# </li>
# <li class="footer_list_item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/structure/commissions/" itemprop="url">Комиссии</a>
# </li>
# <li class="footer_list_item footer_list_item_active" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/structure/machinery/" itemprop="url">Аппарат СФ</a>
# </li>
# <li class="footer_list_item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/structure/chairman_authority/" itemprop="url">Органы при Председателе</a>
# </li>
# <li class="footer_list_item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/structure/sf_authority/" itemprop="url">Органы при Совете Федерации</a>
# </li>
# <li class="footer_list_item footer_list_item_external" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="http://szrf.km.duma.gov.ru/" itemprop="url" target="_blank"><i></i>Совет законодателей при Федеральном Собрании</a>
# </li>
# </ul>
# </div>
# <div class="footer__col col col_4">
# <h2 class="footer_title"><span class="footer_title_link">Деятельность</span></h2>
# <ul class="footer_list">
# <li class="footer_list_item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/activity/meetings/" itemprop="url">Заседания СФ</a>
# </li>
# <li class="footer_list_item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/activity/legislation/" itemprop="url">Законодательная деятельность</a>
# </li>
# <li class="footer_list_item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/activity/documents/" itemprop="url">Документы</a>
# </li>
# <li class="footer_list_item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/activity/crosswork/" itemprop="url">Межпарламентская деятельность</a>
# </li>
# <li class="footer_list_item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/activity/regions/" itemprop="url">Взаимодействие с регионами</a>
# </li>
# <li class="footer_list_item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/activity/activities/" itemprop="url">Мероприятия</a>
# </li>
# <li class="footer_list_item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/activity/anticorruption/" itemprop="url">Противодействие коррупции</a>
# </li>
# <li class="footer_list_item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/activity/reports/" itemprop="url">Ежегодные отчеты сенаторов</a>
# </li>
# <li class="footer_list_item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/activity/analytics/" itemprop="url">Издания и аналитические материалы</a>
# </li>
# </ul>
# </div>
# <div class="footer__col col col_4 last">
# <h2 class="footer_title"><span class="footer_title_link">События</span></h2>
# <ul class="footer_list">
# <li class="footer_list_item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/events/main_themes/" itemprop="url">Главные темы</a>
# </li>
# <li class="footer_list_item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/events/news/" itemprop="url">Все новости</a>
# </li>
# <li class="footer_list_item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/events/chairman/" itemprop="url">Председатель</a>
# </li>
# <li class="footer_list_item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/events/committees/" itemprop="url">Комитеты</a>
# </li>
# <li class="footer_list_item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/events/senators/" itemprop="url">Сенаторы в регионах</a>
# </li>
# <li class="footer_list_item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/events/conference/" itemprop="url">Пресс-конференции</a>
# </li>
# <li class="footer_list_item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/events/blogs/" itemprop="url">Блоги сенаторов</a>
# </li>
# <li class="footer_list_item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/events/multimedia/" itemprop="url">Мультимедиа</a>
# </li>
# <li class="footer_list_item" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/events/streams/" itemprop="url">Телеканал и прямые трансляции</a>
# </li>
# <li class="footer_list_item footer_list_item_smi" itemscope="itemscope" itemtype="http://schema.org/SiteNavigationElement">
# <a href="/events/smi/" itemprop="url"><i></i>Для СМИ</a>
# </li>
# </ul>
# </div>
# <div class="footer__col col col_4 for_mobile" hidden="hidden">
# <h2 class="footer_title"><a class="footer_title_link footer_english_link" href="/en/">English</a></h2>
# </div>
# </div>
# <div class="footer__warpper_bottom">
# <div class="cols footer__info">
# <div class="footer__copy col_2">
# <div class="footer_logo"></div>
# </div>
# <div class="footer__license col_2">
# <div class="">
# <div class="footer_social">
# <ul class="social__list">
# <li class="social__item">
# <a class="social__link footer_social_icon hover_footer_vk" href="https://vk.com/sovfedinfo" target="_blank"><i></i>vk</a>
# </li>
# <li class="social__item">
# <a class="social__link footer_social_icon hover_footer_youtube" href="http://www.youtube.com/user/sovfedinfo" target="_blank"><i></i>Youtube</a>
# </li>
# <li class="social__item social__item_lj">
# <a class="social__link footer_social_icon hover_footer_livej" href="https://ok.ru/sovfedinfo" target="_blank"><i></i>Одноклассники</a>
# </li>
# <li class="social__item">
# <a class="social__link footer_social_icon hover_footer_telegram" href="https://t.me/sovfedofficial " target="_blank"><i></i>Телеграм</a>
# </li>
# <li class="social__item">
# <a class="social__link footer_social_icon hover_footer_rutube" href="https://rutube.ru/channel/23489764/" target="_blank"><i></i>Rutube</a>
# </li>
# <li class="social__item">
# <a class="social__link footer_social_icon hover_footer_flickr" href="https://www.flickr.com/photos/sf_press/albums" target="_blank"><i></i>Flickr</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="footer__address">
# <p class="footer__address_item">Справочная:
#                                         <a class="footer_white" href="tel:+74956297009">+7 495 629-70-09</a></p>
# <p class="footer__address_item footer__address_item_last">Адрес:
#                                         <a class="footer_white" href="https://maps.yandex.ru/?text=г.%20Москва,%20ул.%20Большая%20Дмитровка,%20д.%2026" target="_blank">
#                                            103426, г. Москва,<br/>ул. Большая Дмитровка, д. 26
#                                         </a>
# </p>
# </div>
# </div>
# </div>
# <div class="cols" role="contentinfo">
# <div class="col_2">
# <p><span class="footer__copy_info">Совет Федерации Федерального Собрания Российской Федерации</span>
# </p>
# </div>
# <div class="col_2 common__license">
# <p>Все материалы сайта доступны по лицензии:</p>
# <p><a class="footer_white" href="http://creativecommons.org/licenses/by/4.0/deed.ru" hreflang="ru" rel="license" target="_blank">Creative Commons Attribution 4.0 International</a>
# </p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </footer>
# </div>
# </div>
# <script charset="utf-8" src="/623c6bdd9c657e53ad12a675.js?1663062363039"></script>
# <script src="/static/js/app.js?457f75223e"></script>
# </body>
# </html>

# %% [markdown]
# ## Parse HTML and Translate
# - the `translator.google` method is used here to translate from Russian to English, however, a paid tier service from Google should be considered as this free service takes a long time. Paid service is available here: https://cloud.google.com/translate

# %%
local_sources = get_local_sources(html_filenames)
local_soups = get_local_soups(local_sources)
person_name = get_person_name(local_soups[0])
tables = local_soups[0].find_all('table', {'class':'MsoNormalTable'})
first_table = get_first_table(tables[0])
table_dfs = [get_table_df(table) for table in tables[1:]]
table_dfs_en = get_table_dfs_en(table_dfs)

# %% [markdown]
# # Viewing the Data We've Captured
# - during the testing phase, we only view the tables of one doc file. Later, we will be iterating over all files eventually and saving this data to CSV.
# - Should we be capturing the text outside the tables too?

# %%
person_name
# Out:
# 'Agaltsova Valery Stanislavovich'

# %%
first_table
# Out:
# ('Replaced position',
#  'Deputy Head of the Department of International Relations')

# %%
table_dfs_en[0]
# Out:
#    № n/p                                     Type of income  \
# 0    1.0  Declated annual income of the Federal State Ci...
# 1    2.0           Declared annual income of family members
# 2    NaN                                            Spouses
#
#    The amount of income (rub.)
# 0                    1843996.0
# 1                          NaN
# 2                    1369600.0

# %%
table_dfs_en[1]
# Out:
#          № n/p                     Type of property Square (sq.m)  \
# 0        Land:                                Land:         Land:
# 1            1  for individual housing construction       1514.00
# 2            2          for gardening and gardening       1354.00
# 3            3  for individual housing construction       1504.00
# 4  Apartments:                          Apartments:   Apartments:
# 5            4                                 flat        164.00
# 6            5                                 flat         53.80
# 7    Cottages:                            Cottages:     Cottages:
# 8            6          cottage with farm buildings        100.00
# 9          NaN                                  NaN           NaN
#
#      Square (sq.m) .1    Land of location The owner of the property  \
# 0               Land:               Land:                     Land:
# 1  Russian Federation  Russian Federation        Russian Federation
# 2  Russian Federation  Russian Federation        Russian Federation
# 3  Russian Federation  Russian Federation        Russian Federation
# 4         Apartments:         Apartments:               Apartments:
# 5  Russian Federation  Russian Federation        Russian Federation
# 6  Russian Federation  Russian Federation        Russian Federation
# 7           Cottages:           Cottages:                 Cottages:
# 8  Russian Federation  Russian Federation        Russian Federation
# 9                 NaN                 NaN                       NaN
#
#   Owner of property. 1
# 0                Land:
# 1        Agaltsov V.S.
# 2                 wife
# 3                 wife
# 4          Apartments:
# 5        Agaltsov V.S.
# 6                 wife
# 7            Cottages:
# 8                 wife
# 9                  NaN

# %%
table_dfs_en[2]
# Out:
#    № n/p      № n/p.1 Type of property Square (sq.m.) Square (sq.m.). 1  \
# 0    NaN        Land:            Land:          Land:             Land:
# 1    NaN            1        Land plot      Land plot           2500.00
# 2    NaN  Apartments:      Apartments:    Apartments:       Apartments:
# 3    NaN            2             flat           flat             53.80
# 4    NaN            3             flat           flat            164.00
# 5    NaN          NaN              NaN            NaN               NaN
#
#     Square (sq.m.). 2    Land of location       Who is in use  \
# 0               Land:               Land:               Land:
# 1  Russian Federation  Russian Federation  Russian Federation
# 2         Apartments:         Apartments:         Apartments:
# 3  Russian Federation  Russian Federation  Russian Federation
# 4  Russian Federation  Russian Federation  Russian Federation
# 5                 NaN                 NaN                 NaN
#
#   Who has in use. 1      Unnamed: 9
# 0             Land:           Land:
# 1              wife            wife
# 2       Apartments:     Apartments:
# 3    Minor daughter  Minor daughter
# 4         Minor son       Minor son
# 5               NaN             NaN

# %%
table_dfs_en[3]
# Out:
#              № n/p         Type and brand of vehicles The owner of the vehicle
# 0  Passenger cars:                    Passenger cars:          Passenger cars:
# 1                1  Mercedes-Benz Jil 350 Sidi 4matic            Agaltsov V.S.
# 2                2                          Audi Kew5                     wife
